# %% [markdown]
# # SIM Pattern Generator
#
# ### The Python version
#
# From the [SI of the paper](http://www.pnas.org/content/suppl/2012/03/15/1119262109.DCSupplemental/pnas.201119262SI.pdf):

# %%
# %pylab inline
# nice plotting
# import seaborn as sns
import numexpr as ne
# for minimizing the difference between the desired frequency and the calculated one
from scipy.optimize import minimize
# Need to be able to do polynomial fitting
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
# PIL allows us to write binary images, though we need a cludge, see 'Writing Binary Files.ipynb'
from PIL import Image
import os
import zipfile
from pyfftw.interfaces.numpy_fft import fftn
import pyfftw
pyfftw.interfaces.cache.enable()
from scipy.ndimage import gaussian_filter

from skimage.draw import circle

from matplotlib.colors import LogNorm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# newest one
def pattern_gen(angle, period, onfrac = 0.5, phase_idx = 0., phase_offset = 0., nphases =5,
                sizex =2048, sizey =1536, SIM_2D = True):
    '''
    Generates a binary SLM pattern for SIM
    
    Generates a sine wave and then binarizes it
    
    designed for my orientation
    
    Parameters
    ----------
    x : array_like
        the $\vec{a}$ from [1]. Defines the pattern orientation
    period : float
        Defines the period of the pattern
    onfrac : float
        The fraction of on pixels in the pattern
    phase_idx : int
        The phase of the pattern (see `nphases` for more info)
    phase_offset : float
        The offset in phase, mostly used for aligning patterns of different colors
    nphases : int
        the number of phases
    sizex : int
        size of the pattern
    sizey : int
        size of the pattern

    Returns
    -------
    pattern : ndarray
        A binary array representing a single bitplane to send to the SLM
    '''
    
    if not 0 < onfrac < 1:
        raise ValueError('onfrac must have a value between 0 and 1. onfrac = {}'.format(onfrac))
    
    
    if SIM_2D:
        # Then we only want to take steps of 2pi/n in illumination which means pi/n at the SLM
        phase_step = 2
    else:
        phase_step = 1
    
    # indices are backwards here for backwards compatability with older generation code.
    yy, xx = meshgrid(arange(sizey),arange(sizex),indexing='ij')
    
    # here's the pattern frequency
    freq = 2*pi/period
    
    phi = (phase_idx/nphases/phase_step)*(2*pi) + phase_offset
    
    # our sine goes from -1 to 1 while onfrac goes from 0,1 so move onfrac into the right range
    onfrac = onfrac*2-1
    
    # given angle is the angle of the fourier spots from the 'i' vector, so pattern should be 90 degrees from this
    a = angle
    
    # do the evaluation
    toreturn = ne.evaluate("sin(freq*(cos(a)*xx+sin(a)*yy)+phi) > onfrac")
    
    return toreturn

# %%
def angles(init_angle, num_angles):
    thetas = arange(0., num_angles)*pi/1./num_angles + init_angle
    return thetas

# %%
def ideal_period(wavelength, NA = 0.85):
    '''
    All units are in mm
    '''
    pixel_size = 8.2/1000 # pixel size in mm for QXGA display (4DD)
    fl = 250 # focal length of lens in mm
    fl2 = 300 # focal length of the second lens
    ftube = 200 # focal length of the tube lens, for Nikon this is 200 mm
    wl = wavelength/10**6 # wavelength of light
    mag = 1/100
    sigma = sqrt(2) * 12/pixel_size/4 # std dev of gaussian beam in units of pixels at the SLM
    pupil_diameter = 2*NA*mag*fl2    # Size of pupil image at first fourier plane
    hole_radius = 2*wl*fl/(2* pi * sigma *sqrt(2) * pixel_size) # this is the limit of hole size
    hole_radius = 0.1/2# this is more reasonable (50 um)
    period = wl * fl * (1/(pupil_diameter/2 - hole_radius))/ pixel_size # in mm
    
    return period

# %%
def pattern_params(angle, period, onfrac = 0.5, phaseInd = 0., phaseOffset = 0., nphases = 5, sizex =2048, sizey =1536):
    '''
    Find the precise pattern period
    
    Using 2nd order polynomial fit along either axis
    '''
    
    # this is a standin for nextpow2, I don't know if there's a more efficient one, but its not going to
    # be a bottle neck
    n = 1<<(min(sizex,sizey)-1).bit_length()
    
    my_pat = pattern_gen(angle, period, onfrac, phaseInd, phaseOffset, nphases, n, n)
    
    my_pat_fft = abs(ifftshift(fftn(fftshift(my_pat))))

    dc_loc = ((np.array(my_pat_fft.shape)+1)//2)
    
    # make mask
    mask = ones_like(my_pat_fft)
    mask[circle(*dc_loc,radius=10)]=0
    mask[:dc_loc[0]]=0
    
    # mask data and find next biggest peak
    masked_fft_data = abs(mask*my_pat_fft)
    max_loc = unravel_index(masked_fft_data.argmax(),masked_fft_data.shape)
    # pull the 3x3 region around the peak
    region_size = 3
    start = -(region_size-1)//2
    end = region_size+start

    my_pat_fft_suby = masked_fft_data[max_loc[0]+start:max_loc[0]+end,max_loc[1]]
    my_pat_fft_subx = masked_fft_data[max_loc[0],max_loc[1]+start:max_loc[1]+end]

    x = arange(start,end)
    
    xfit = polyfit(x, my_pat_fft_subx,2)
    yfit = polyfit(x, my_pat_fft_suby,2)

    x0 = -xfit[1]/(2*xfit[0])
    y0 = -yfit[1]/(2*yfit[0])

    precisepeak = array(max_loc)+array([x0,y0])-array(dc_loc)

    preciseangle = arctan2(precisepeak[0],precisepeak[1])
    
    if angle < 0:
        preciseangle -= pi
    
    precise_period = n/norm(precisepeak)
    
    return {"period" : precise_period, "angle" : preciseangle, "pat" : my_pat, "pat fft" : my_pat_fft}

# %%
def opt_period(iperiod,angle,**kwargs):
    def objf_l1(period):
        data = array([pattern_params(angle, period, **kwargs)['period'] for n in range(1)])
        return mean(abs(data-iperiod))
    
    return minimize(objf_l1, iperiod ,method='Nelder-Mead')['x']

# %%
def opt_angle(period,iangle,**kwargs):
    def objf_l1(angle):
        data = array([pattern_params(angle, period, **kwargs)['angle'] for n in range(1)])
        return mean(abs(data-iangle))
    
    return minimize(objf_l1, iperiod ,method='Nelder-Mead')['x']

# %%
'''
We can use sets as a way to keep track of images and sequences.

Images and sequences will be denoted by strings referring to the actual file name

A repetoire will only contain a list of RunningOrders and have a method to write out running orders.

It should also have the ability to read in a .rep file

Need a method to return a given running order, by name
'''

class RunningOrder(object):
    '''
    A class representing a running order for a 4DD SLM
    '''
    
    def __init__(self, name, angles=3, periods=1, triggered = True):
        self._name = name
        self._periods = periods
        self._angles = angles
        # we want these properties to be immutable and we don't want duplicates
        self._sequences = set()
        self._bitplanes = set()
        self.triggered = triggered
        self._RO = []
        
    @property
    def name(self):
        return self._name
    
    @property
    def periods(self):
        return self._periods
    
    @property
    def angles(self):
        return self._angles
    
    @property
    def sequences(self):
        return self._sequences
    
    @property
    def bitplanes(self):
        return self._bitplanes
    
    @property
    def RO(self):
        return self._RO
    
    def addbitplane(self, sequence, bitplane, position = None):
        '''
        A function to add sequence bitplane pairs to a running order
        '''
        self._sequences.add(sequence)
        self._bitplanes.add(bitplane)
            
        seq_bp = {'sequence' : sequence, 'bitplane' : bitplane}
        
        if position is None:
            self._RO.append(seq_bp)
        else:
            self._RO.insert(position, seq_bp)

class Repetoire(object):
    '''
    This object holds a list of Running orders. It has the ability to output .rep files
    
    Further functionality will be to read in .rep files.
    '''
    
    def __init__(self, listofROs = None):
        self._ROs = []
        self._sequences = set()
        self._bitplanes = set()
        if listofROs is not None:
            for RO in listofROs:
                self.add_RO(RO)
        
    def add_RO(self, RO):
        
        if isinstance(RO, list):
            self.add_RO(RO.pop())
        
        if not isinstance(RO, RunningOrder):
            raise TypeError('{} is not a RunningOrder'.format(RO))
        else:
            self._ROs.append(RO)
            self._sequences |= RO.sequences
            self._bitplanes |= RO.bitplanes

    def __str__(self):
        '''
        This function writes the repetoire
        '''
        
        toreturn = ''
        
        # If ROs is empty
        if not len(self._ROs):
            return toreturn
        
        # # # # # # # # # # # # # # # # # # # # 
        # MAKING SEQUENCES # 
        # # # # # # # # # # # # # # # # # # # # 
        
        # need to save the letter assignments
        seq_dict = {}
        
        seqs = ['SEQUENCES']
        for i, seq in enumerate(sorted(self._sequences)):
            char = chr(65+i)
            seqs.append(char+' "'+seq+'"')
            seq_dict[seq] = char
        
        seqs.append('SEQUENCES_END\n\n')
        
        toreturn = "\n".join(seqs)
        
        # # # # # # # # # # # # # # # # # # # # 
        # MAKING BITPLANES # 
        # # # # # # # # # # # # # # # # # # # # 
        
        bp_dict = {}
        bps = ['IMAGES']
        for i, bp in enumerate(sorted(self._bitplanes)):
            bps.append('1 "'+bp+'"')
            bp_dict[bp] = i
        
        bps.append('IMAGES_END\n\n')
        
        toreturn += "\n".join(bps)
        
        # Need to have at least one RunningOrder be Default, why not the first one?
        # If no DEFAULT then MetroCon will continue to look for one and fail.
        toreturn += 'DEFAULT '
        # sort the RunningOrders by name
        for RO in self._ROs:# .sort(key=lambda x: x.name):
            toreturn += self._writeRO(RO, seq_dict, bp_dict)
            
        return toreturn
        
    @staticmethod
    def _writeRO(RO, seq_dict, bp_dict):
        '''
        This function will write the repetoire based on the sequence dict and image dict
        
        It assumes that all that is wanted is standard SIM sequences
        '''
        
        toreturn = ['"{}"'.format(RO.name)]
        
        toreturn.append('[HWA\n')
        

        if not RO.triggered:
            toappend = ' {'
            
        try:
            a = array(RO.RO).reshape(RO.angles,-1)
        except ValueError:
            raise ValueError('{} has length = {} which is not divisible by {}'.format(RO.name, len(RO.RO), RO.angles))
        else:
            for angle in array(RO.RO).reshape(RO.angles,-1):
                for i in range(RO.periods):
                    for seq_bp in angle:
                        seq = seq_bp['sequence']
                        bp = seq_bp['bitplane']
                        if RO.triggered:
                            toreturn.append(' <t({0},{1}) >\n {{f ({0},{1}) }}'.format(seq_dict[seq],bp_dict[bp]))
                        else:
                            toappend += '({0},{1}) '.format(seq_dict[seq],bp_dict[bp])

        if not RO.triggered:
            toappend += '}'
            toreturn.append(toappend)

        toreturn.append(']\n\n')
        
        return '\n'.join(toreturn)

# %%
# Super SIM for 5 orientations
onfrac = 0.5
num_angles = 5
my_angles = angles(deg2rad(9.0),num_angles)
    
num_phases = 15
num_periods = 1

wls = (561,488)

repname = 'SuperSIM488_561_2D_5orients_9deg'
# open zip file, make sure the compression is set to ZIP_DEFLATED (8)
with zipfile.ZipFile('{}.repz11'.format(repname), 'w', compression=zipfile.ZIP_DEFLATED) as myzip:

    opt = False

    my_dir = os.path.join('{}'.format(repname),'')
    if not os.path.isdir(my_dir):
        print('Making ' + my_dir)
        os.mkdir(my_dir)
    
    NAs = (0.81, 0.82, 0.83, 0.84)
    
    ROlist = []
    
    seq = '48070 HHMI 10ms.seq11'
    seq2 = '48077 HHMI 24 50ms.seq11'
    
    for myseq in (seq,):
        myzip.write(os.path.join('HHMI_R11_Seq', myseq),arcname=myseq)
    
    for wl in wls:
        for NA in NAs:
            print('{} nm, NA {}'.format(wl,NA))

            iperiod = ideal_period(wl,NA=NA)
            # ROs here
            super_RO = RunningOrder('{} nm Super SIM {}pi NA {}'.format(wl, num_periods*2, NA),
                                    angles=num_angles, periods=num_periods)
            reg_RO_3 = RunningOrder('{} nm SIM NA {} 3 phases'.format(wl,NA), angles=num_angles)
            reg_RO_5 = RunningOrder('{} nm SIM NA {} 5 phases'.format(wl,NA), angles=num_angles)

            RO_all_t = RunningOrder('{} nm NA {} All Orientations Triggered'.format(wl,NA), angles=1)
            RO_all = RunningOrder('{} nm NA {} All Orientations'.format(wl,NA), triggered=False, angles=1)

            patall =zeros((1536, 2048))

            for angle in my_angles:

                # calculate degree from angle for filename
                degree = rad2deg(angle)

                RO1orient = RunningOrder('{} nm NA {} {:+.2f} degrees'.format(wl, NA, degree), angles=1, triggered=False)

                # optimize the angle
                if opt:
                    print('Optimizing angle = {:+.2f} degrees'.format(degree))
                    my_per = opt_period(iperiod,angle)[0]
                else:
                    my_per = iperiod

                for phase in range(num_phases):
                    # generate pattern, with one period,
                    pat = pattern_gen(angle, my_per,onfrac=onfrac,phase_idx=phase,nphases=num_phases,SIM_2D=True)

                    # make image object
                    pat_img = Image.fromarray((pat*255).astype('uint8'),mode='L')

                    # generate filename, put orientation in front, so that its consistent
                    name = 'pat-{}nm-{:.2f}NA{:+.1f}deg-{:02d}ph-{:.4f}pix-{:.2f}DC.bmp'.format(wl,NA, degree,phase,my_per,onfrac)

                    # convert to binary and save
                    pat_img.convert('1').save(os.path.join(my_dir,name))

                    # move to zip file and save
                    myzip.write(os.path.join(my_dir,name),arcname=name)

                    super_RO.addbitplane(seq,name)

                    if not phase:
                        RO1orient.addbitplane(seq,name)
                        # add to all angles pattern
                        patall += pat

                    # only pull the first three phases so that we can do regular SIM too
                    if (phase % (num_phases//3) == 0):
                        # num_phases//desired number of phases will calculate the right divisor
                        # check
                        assert num_phases % 3 == 0
                        reg_RO_3.addbitplane(seq,name)
                    if (phase % (num_phases//5) == 0):
                        assert num_phases % 5 == 0
                        reg_RO_5.addbitplane(seq,name)

                    print('Wrote file: {}'.format(name))

                ROlist.append(RO1orient)

            # make image object for all
            patall_img = Image.fromarray((patall/num_angles*255).astype('uint8'),mode='L')

            # generate filename, put orientation in front, so that its consistent
            nameall = 'pat-{}nm-{:.2f}NA-{:.4f}pix-{:.2f}DC_allangles.bmp'.format(wl,NA,my_per,onfrac)

            # convert to binary and save
            patall_img.convert('1').save(os.path.join(my_dir,nameall))

            # move to zip file and save
            myzip.write(os.path.join(my_dir,nameall),arcname=nameall)

            RO_all_t.addbitplane(seq,nameall)
            RO_all.addbitplane(seq,nameall)

            ROlist.append(super_RO)
            ROlist.append(reg_RO_3)
            ROlist.append(reg_RO_5)
            ROlist.append(RO_all_t)
            ROlist.append(RO_all)
                
    my_Rep = Repetoire(ROlist)
    
    # write the rep file
    with open(os.path.join(my_dir,'{}.rep'.format(repname)),'w') as repfile:
        repfile.write(str(my_Rep))
        
    # now add the file to the zip
    myzip.write(os.path.join(my_dir,'{}.rep'.format(repname)),arcname='{}.rep'.format(repname))
    
print(my_Rep)
# Out:
# 561 nm, NA 0.81
# Wrote file: pat-561nm-0.81NA+9.0deg-00ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-01ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-02ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-03ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-04ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-05ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-06ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-07ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-08ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-09ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-10ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-11ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-12ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-13ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+9.0deg-14ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-00ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-01ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-02ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-03ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-04ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-05ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-06ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-07ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-08ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-09ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-10ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-11ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-12ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-13ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+45.0deg-14ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-00ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-01ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-02ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-03ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-04ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-05ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-06ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-07ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-08ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-09ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-10ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-11ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-12ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-13ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+81.0deg-14ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-00ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-01ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-02ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-03ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-04ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-05ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-06ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-07ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-08ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-09ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-10ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-11ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-12ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-13ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+117.0deg-14ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-00ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-01ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-02ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-03ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-04ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-05ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-06ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-07ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-08ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-09ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-10ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-11ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-12ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-13ph-7.1864pix-0.50DC.bmp
# Wrote file: pat-561nm-0.81NA+153.0deg-14ph-7.1864pix-0.50DC.bmp
# 561 nm, NA 0.82
# Wrote file: pat-561nm-0.82NA+9.0deg-00ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-01ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-02ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-03ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-04ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-05ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-06ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-07ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-08ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-09ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-10ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-11ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-12ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-13ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+9.0deg-14ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-00ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-01ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-02ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-03ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-04ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-05ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-06ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-07ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-08ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-09ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-10ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-11ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-12ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-13ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+45.0deg-14ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-00ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-01ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-02ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-03ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-04ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-05ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-06ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-07ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-08ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-09ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-10ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-11ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-12ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-13ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+81.0deg-14ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-00ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-01ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-02ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-03ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-04ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-05ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-06ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-07ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-08ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-09ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-10ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-11ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-12ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-13ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+117.0deg-14ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-00ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-01ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-02ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-03ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-04ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-05ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-06ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-07ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-08ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-09ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-10ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-11ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-12ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-13ph-7.0970pix-0.50DC.bmp
# Wrote file: pat-561nm-0.82NA+153.0deg-14ph-7.0970pix-0.50DC.bmp
# 561 nm, NA 0.83
# Wrote file: pat-561nm-0.83NA+9.0deg-00ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-01ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-02ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-03ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-04ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-05ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-06ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-07ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-08ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-09ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-10ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-11ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-12ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-13ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+9.0deg-14ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-00ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-01ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-02ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-03ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-04ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-05ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-06ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-07ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-08ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-09ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-10ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-11ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-12ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-13ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+45.0deg-14ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-00ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-01ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-02ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-03ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-04ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-05ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-06ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-07ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-08ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-09ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-10ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-11ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-12ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-13ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+81.0deg-14ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-00ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-01ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-02ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-03ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-04ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-05ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-06ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-07ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-08ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-09ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-10ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-11ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-12ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-13ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+117.0deg-14ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-00ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-01ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-02ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-03ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-04ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-05ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-06ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-07ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-08ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-09ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-10ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-11ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-12ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-13ph-7.0097pix-0.50DC.bmp
# Wrote file: pat-561nm-0.83NA+153.0deg-14ph-7.0097pix-0.50DC.bmp
# 561 nm, NA 0.84
# Wrote file: pat-561nm-0.84NA+9.0deg-00ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-01ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-02ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-03ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-04ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-05ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-06ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-07ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-08ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-09ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-10ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-11ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-12ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-13ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+9.0deg-14ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-00ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-01ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-02ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-03ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-04ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-05ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-06ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-07ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-08ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-09ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-10ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-11ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-12ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-13ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+45.0deg-14ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-00ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-01ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-02ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-03ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-04ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-05ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-06ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-07ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-08ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-09ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-10ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-11ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-12ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-13ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+81.0deg-14ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-00ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-01ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-02ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-03ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-04ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-05ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-06ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-07ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-08ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-09ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-10ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-11ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-12ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-13ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+117.0deg-14ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-00ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-01ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-02ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-03ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-04ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-05ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-06ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-07ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-08ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-09ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-10ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-11ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-12ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-13ph-6.9246pix-0.50DC.bmp
# Wrote file: pat-561nm-0.84NA+153.0deg-14ph-6.9246pix-0.50DC.bmp
# 488 nm, NA 0.81
# Wrote file: pat-488nm-0.81NA+9.0deg-00ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-01ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-02ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-03ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-04ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-05ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-06ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-07ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-08ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-09ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-10ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-11ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-12ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-13ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-14ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-00ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-01ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-02ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-03ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-04ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-05ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-06ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-07ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-08ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-09ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-10ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-11ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-12ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-13ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-14ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-00ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-01ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-02ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-03ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-04ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-05ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-06ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-07ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-08ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-09ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-10ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-11ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-12ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-13ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-14ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-00ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-01ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-02ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-03ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-04ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-05ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-06ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-07ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-08ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-09ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-10ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-11ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-12ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-13ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-14ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-00ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-01ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-02ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-03ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-04ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-05ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-06ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-07ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-08ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-09ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-10ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-11ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-12ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-13ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-14ph-6.2513pix-0.50DC.bmp
# 488 nm, NA 0.82
# Wrote file: pat-488nm-0.82NA+9.0deg-00ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-01ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-02ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-03ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-04ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-05ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-06ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-07ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-08ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-09ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-10ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-11ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-12ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-13ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-14ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-00ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-01ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-02ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-03ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-04ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-05ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-06ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-07ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-08ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-09ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-10ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-11ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-12ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-13ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-14ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-00ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-01ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-02ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-03ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-04ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-05ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-06ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-07ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-08ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-09ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-10ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-11ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-12ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-13ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-14ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-00ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-01ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-02ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-03ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-04ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-05ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-06ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-07ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-08ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-09ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-10ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-11ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-12ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-13ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-14ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-00ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-01ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-02ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-03ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-04ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-05ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-06ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-07ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-08ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-09ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-10ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-11ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-12ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-13ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-14ph-6.1735pix-0.50DC.bmp
# 488 nm, NA 0.83
# Wrote file: pat-488nm-0.83NA+9.0deg-00ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-01ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-02ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-03ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-04ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-05ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-06ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-07ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-08ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-09ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-10ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-11ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-12ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-13ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+9.0deg-14ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-00ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-01ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-02ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-03ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-04ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-05ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-06ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-07ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-08ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-09ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-10ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-11ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-12ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-13ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+45.0deg-14ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-00ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-01ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-02ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-03ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-04ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-05ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-06ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-07ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-08ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-09ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-10ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-11ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-12ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-13ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+81.0deg-14ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-00ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-01ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-02ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-03ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-04ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-05ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-06ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-07ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-08ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-09ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-10ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-11ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-12ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-13ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+117.0deg-14ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-00ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-01ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-02ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-03ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-04ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-05ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-06ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-07ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-08ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-09ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-10ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-11ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-12ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-13ph-6.0976pix-0.50DC.bmp
# Wrote file: pat-488nm-0.83NA+153.0deg-14ph-6.0976pix-0.50DC.bmp
# 488 nm, NA 0.84
# Wrote file: pat-488nm-0.84NA+9.0deg-00ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-01ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-02ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-03ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-04ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-05ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-06ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-07ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-08ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-09ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-10ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-11ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-12ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-13ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+9.0deg-14ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-00ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-01ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-02ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-03ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-04ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-05ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-06ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-07ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-08ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-09ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-10ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-11ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-12ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-13ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+45.0deg-14ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-00ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-01ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-02ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-03ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-04ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-05ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-06ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-07ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-08ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-09ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-10ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-11ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-12ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-13ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+81.0deg-14ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-00ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-01ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-02ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-03ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-04ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-05ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-06ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-07ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-08ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-09ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-10ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-11ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-12ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-13ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+117.0deg-14ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-00ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-01ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-02ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-03ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-04ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-05ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-06ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-07ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-08ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-09ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-10ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-11ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-12ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-13ph-6.0235pix-0.50DC.bmp
# Wrote file: pat-488nm-0.84NA+153.0deg-14ph-6.0235pix-0.50DC.bmp
# SEQUENCES
# A "48070 HHMI 10ms.seq11"
# SEQUENCES_END
#
# IMAGES
# 1 "pat-488nm-0.81NA+117.0deg-00ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-01ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-02ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-03ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-04ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-05ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-06ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-07ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-08ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-09ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-10ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-11ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-12ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-13ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-14ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-00ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-01ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-02ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-03ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-04ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-05ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-06ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-07ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-08ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-09ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-10ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-11ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-12ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-13ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-14ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-00ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-01ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-02ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-03ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-04ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-05ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-06ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-07ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-08ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-09ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-10ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-11ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-12ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-13ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-14ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-00ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-01ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-02ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-03ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-04ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-05ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-06ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-07ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-08ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-09ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-10ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-11ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-12ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-13ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-14ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-00ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-01ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-02ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-03ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-04ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-05ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-06ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-07ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-08ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-09ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-10ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-11ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-12ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-13ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-14ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA-6.2513pix-0.50DC_allangles.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-00ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-01ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-02ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-03ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-04ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-05ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-06ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-07ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-08ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-09ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-10ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-11ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-12ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-13ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-14ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-00ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-01ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-02ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-03ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-04ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-05ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-06ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-07ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-08ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-09ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-10ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-11ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-12ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-13ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-14ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-00ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-01ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-02ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-03ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-04ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-05ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-06ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-07ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-08ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-09ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-10ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-11ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-12ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-13ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-14ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-00ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-01ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-02ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-03ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-04ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-05ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-06ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-07ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-08ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-09ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-10ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-11ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-12ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-13ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-14ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-00ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-01ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-02ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-03ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-04ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-05ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-06ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-07ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-08ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-09ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-10ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-11ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-12ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-13ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-14ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA-6.1735pix-0.50DC_allangles.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-00ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-01ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-02ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-03ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-04ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-05ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-06ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-07ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-08ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-09ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-10ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-11ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-12ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-13ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+117.0deg-14ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-00ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-01ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-02ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-03ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-04ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-05ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-06ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-07ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-08ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-09ph-6.0976pix-0.50DC.bmp"
# 1 "pat-488nm-0.83NA+153.0deg-10ph-6.0976pix-0.50DC.bmp"
# ...
#  {f (A,541) }
#  <t(A,542) >
#  {f (A,542) }
#  <t(A,543) >
#  {f (A,543) }
#  <t(A,544) >
#  {f (A,544) }
#  <t(A,545) >
#  {f (A,545) }
#  <t(A,546) >
#  {f (A,546) }
#  <t(A,547) >
#  {f (A,547) }
#  <t(A,548) >
#  {f (A,548) }
#  <t(A,549) >
#  {f (A,549) }
#  <t(A,550) >
#  {f (A,550) }
#  <t(A,551) >
#  {f (A,551) }
#  <t(A,552) >
#  {f (A,552) }
#  <t(A,553) >
#  {f (A,553) }
#  <t(A,554) >
#  {f (A,554) }
#  <t(A,555) >
#  {f (A,555) }
#  <t(A,556) >
#  {f (A,556) }
#  <t(A,557) >
#  {f (A,557) }
#  <t(A,558) >
#  {f (A,558) }
#  <t(A,559) >
#  {f (A,559) }
#  <t(A,560) >
#  {f (A,560) }
#  <t(A,561) >
#  {f (A,561) }
# ]
#
# "561 nm SIM NA 0.84 3 phases"
# [HWA
#
#  <t(A,592) >
#  {f (A,592) }
#  <t(A,597) >
#  {f (A,597) }
#  <t(A,602) >
#  {f (A,602) }
#  <t(A,562) >
#  {f (A,562) }
#  <t(A,567) >
#  {f (A,567) }
#  <t(A,572) >
#  {f (A,572) }
#  <t(A,577) >
#  {f (A,577) }
#  <t(A,582) >
#  {f (A,582) }
#  <t(A,587) >
#  {f (A,587) }
#  <t(A,532) >
#  {f (A,532) }
#  <t(A,537) >
#  {f (A,537) }
#  <t(A,542) >
#  {f (A,542) }
#  <t(A,547) >
#  {f (A,547) }
#  <t(A,552) >
#  {f (A,552) }
#  <t(A,557) >
#  {f (A,557) }
# ]
#
# "561 nm SIM NA 0.84 5 phases"
# [HWA
#
#  <t(A,592) >
#  {f (A,592) }
#  <t(A,595) >
#  {f (A,595) }
#  <t(A,598) >
#  {f (A,598) }
#  <t(A,601) >
#  {f (A,601) }
#  <t(A,604) >
#  {f (A,604) }
#  <t(A,562) >
#  {f (A,562) }
#  <t(A,565) >
#  {f (A,565) }
#  <t(A,568) >
#  {f (A,568) }
#  <t(A,571) >
#  {f (A,571) }
#  <t(A,574) >
#  {f (A,574) }
#  <t(A,577) >
#  {f (A,577) }
#  <t(A,580) >
#  {f (A,580) }
#  <t(A,583) >
#  {f (A,583) }
#  <t(A,586) >
#  {f (A,586) }
#  <t(A,589) >
#  {f (A,589) }
#  <t(A,532) >
#  {f (A,532) }
#  <t(A,535) >
#  {f (A,535) }
#  <t(A,538) >
#  {f (A,538) }
#  <t(A,541) >
#  {f (A,541) }
#  <t(A,544) >
#  {f (A,544) }
#  <t(A,547) >
#  {f (A,547) }
#  <t(A,550) >
#  {f (A,550) }
#  <t(A,553) >
#  {f (A,553) }
#  <t(A,556) >
#  {f (A,556) }
#  <t(A,559) >
#  {f (A,559) }
# ]
#
# "561 nm NA 0.84 All Orientations Triggered"
# [HWA
#
#  <t(A,607) >
#  {f (A,607) }
# ]
#
# "561 nm NA 0.84 All Orientations"
# [HWA
#
#  {(A,607) }
# ]
#
# "488 nm NA 0.81 +9.00 degrees"
# [HWA
#
#  {(A,60) }
# ]
#
# "488 nm NA 0.81 +45.00 degrees"
# [HWA
#
#  {(A,30) }
# ]
#
# "488 nm NA 0.81 +81.00 degrees"
# [HWA
#
#  {(A,45) }
# ]
#
# "488 nm NA 0.81 +117.00 degrees"
# [HWA
#
#  {(A,0) }
# ]
#
# "488 nm NA 0.81 +153.00 degrees"
# [HWA
#
#  {(A,15) }
# ]
#
# "488 nm Super SIM 2pi NA 0.81"
# [HWA
#
#  <t(A,60) >
#  {f (A,60) }
#  <t(A,61) >
#  {f (A,61) }
#  <t(A,62) >
#  {f (A,62) }
#  <t(A,63) >
#  {f (A,63) }
#  <t(A,64) >
#  {f (A,64) }
#  <t(A,65) >
#  {f (A,65) }
#  <t(A,66) >
#  {f (A,66) }
#  <t(A,67) >
#  {f (A,67) }
#  <t(A,68) >
#  {f (A,68) }
#  <t(A,69) >
#  {f (A,69) }
#  <t(A,70) >
#  {f (A,70) }
#  <t(A,71) >
#  {f (A,71) }
#  <t(A,72) >
#  {f (A,72) }
#  <t(A,73) >
#  {f (A,73) }
#  <t(A,74) >
#  {f (A,74) }
#  <t(A,30) >
#  {f (A,30) }
#  <t(A,31) >
#  {f (A,31) }
#  <t(A,32) >
#  {f (A,32) }
#  <t(A,33) >
#  {f (A,33) }
#  <t(A,34) >
#  {f (A,34) }
#  <t(A,35) >
#  {f (A,35) }
#  <t(A,36) >
#  {f (A,36) }
#  <t(A,37) >
#  {f (A,37) }
#  <t(A,38) >
#  {f (A,38) }
#  <t(A,39) >
#  {f (A,39) }
#  <t(A,40) >
#  {f (A,40) }
#  <t(A,41) >
#  {f (A,41) }
#  <t(A,42) >
#  {f (A,42) }
#  <t(A,43) >
#  {f (A,43) }
#  <t(A,44) >
#  {f (A,44) }
#  <t(A,45) >
#  {f (A,45) }
#  <t(A,46) >
#  {f (A,46) }
#  <t(A,47) >
#  {f (A,47) }
#  <t(A,48) >
#  {f (A,48) }
#  <t(A,49) >
#  {f (A,49) }
#  <t(A,50) >
#  {f (A,50) }
#  <t(A,51) >
#  {f (A,51) }
#  <t(A,52) >
#  {f (A,52) }
#  <t(A,53) >
#  {f (A,53) }
#  <t(A,54) >
#  {f (A,54) }
#  <t(A,55) >
#  {f (A,55) }
#  <t(A,56) >
#  {f (A,56) }
#  <t(A,57) >
#  {f (A,57) }
#  <t(A,58) >
#  {f (A,58) }
#  <t(A,59) >
#  {f (A,59) }
#  <t(A,0) >
#  {f (A,0) }
#  <t(A,1) >
#  {f (A,1) }
#  <t(A,2) >
#  {f (A,2) }
#  <t(A,3) >
#  {f (A,3) }
#  <t(A,4) >
#  {f (A,4) }
#  <t(A,5) >
#  {f (A,5) }
#  <t(A,6) >
#  {f (A,6) }
#  <t(A,7) >
#  {f (A,7) }
#  <t(A,8) >
#  {f (A,8) }
#  <t(A,9) >
#  {f (A,9) }
#  <t(A,10) >
#  {f (A,10) }
#  <t(A,11) >
#  {f (A,11) }
#  <t(A,12) >
#  {f (A,12) }
#  <t(A,13) >
#  {f (A,13) }
#  <t(A,14) >
#  {f (A,14) }
#  <t(A,15) >
#  {f (A,15) }
#  <t(A,16) >
#  {f (A,16) }
#  <t(A,17) >
#  {f (A,17) }
#  <t(A,18) >
#  {f (A,18) }
#  <t(A,19) >
#  {f (A,19) }
#  <t(A,20) >
#  {f (A,20) }
#  <t(A,21) >
#  {f (A,21) }
#  <t(A,22) >
#  {f (A,22) }
#  <t(A,23) >
#  {f (A,23) }
#  <t(A,24) >
#  {f (A,24) }
#  <t(A,25) >
#  {f (A,25) }
#  <t(A,26) >
#  {f (A,26) }
#  <t(A,27) >
#  {f (A,27) }
#  <t(A,28) >
#  {f (A,28) }
#  <t(A,29) >
#  {f (A,29) }
# ]
#
# "488 nm SIM NA 0.81 3 phases"
# [HWA
#
#  <t(A,60) >
#  {f (A,60) }
#  <t(A,65) >
#  {f (A,65) }
#  <t(A,70) >
#  {f (A,70) }
#  <t(A,30) >
#  {f (A,30) }
#  <t(A,35) >
#  {f (A,35) }
#  <t(A,40) >
#  {f (A,40) }
#  <t(A,45) >
#  {f (A,45) }
#  <t(A,50) >
#  {f (A,50) }
#  <t(A,55) >
#  {f (A,55) }
#  <t(A,0) >
#  {f (A,0) }
#  <t(A,5) >
#  {f (A,5) }
#  <t(A,10) >
#  {f (A,10) }
#  <t(A,15) >
#  {f (A,15) }
#  <t(A,20) >
#  {f (A,20) }
#  <t(A,25) >
#  {f (A,25) }
# ]
#
# "488 nm SIM NA 0.81 5 phases"
# [HWA
#
#  <t(A,60) >
#  {f (A,60) }
#  <t(A,63) >
#  {f (A,63) }
#  <t(A,66) >
#  {f (A,66) }
#  <t(A,69) >
#  {f (A,69) }
#  <t(A,72) >
#  {f (A,72) }
#  <t(A,30) >
#  {f (A,30) }
#  <t(A,33) >
#  {f (A,33) }
#  <t(A,36) >
#  {f (A,36) }
#  <t(A,39) >
#  {f (A,39) }
#  <t(A,42) >
#  {f (A,42) }
#  <t(A,45) >
#  {f (A,45) }
#  <t(A,48) >
#  {f (A,48) }
#  <t(A,51) >
#  {f (A,51) }
#  <t(A,54) >
#  {f (A,54) }
#  <t(A,57) >
#  {f (A,57) }
#  <t(A,0) >
#  {f (A,0) }
#  <t(A,3) >
#  {f (A,3) }
#  <t(A,6) >
#  {f (A,6) }
#  <t(A,9) >
#  {f (A,9) }
#  <t(A,12) >
#  {f (A,12) }
#  <t(A,15) >
#  {f (A,15) }
#  <t(A,18) >
#  {f (A,18) }
#  <t(A,21) >
#  {f (A,21) }
#  <t(A,24) >
#  {f (A,24) }
#  <t(A,27) >
#  {f (A,27) }
# ]
#
# "488 nm NA 0.81 All Orientations Triggered"
# [HWA
#
#  <t(A,75) >
#  {f (A,75) }
# ]
#
# "488 nm NA 0.81 All Orientations"
# [HWA
#
#  {(A,75) }
# ]
#
# "488 nm NA 0.82 +9.00 degrees"
# [HWA
#
#  {(A,136) }
# ]
#
# "488 nm NA 0.82 +45.00 degrees"
# [HWA
#
#  {(A,106) }
# ]
#
# "488 nm NA 0.82 +81.00 degrees"
# [HWA
#
#  {(A,121) }
# ]
#
# "488 nm NA 0.82 +117.00 degrees"
# [HWA
#
#  {(A,76) }
# ]
#
# "488 nm NA 0.82 +153.00 degrees"
# [HWA
#
#  {(A,91) }
# ]
#
# "488 nm Super SIM 2pi NA 0.82"
# [HWA
#
#  <t(A,136) >
#  {f (A,136) }
#  <t(A,137) >
#  {f (A,137) }
#  <t(A,138) >
#  {f (A,138) }
#  <t(A,139) >
#  {f (A,139) }
#  <t(A,140) >
#  {f (A,140) }
#  <t(A,141) >
#  {f (A,141) }
#  <t(A,142) >
#  {f (A,142) }
#  <t(A,143) >
#  {f (A,143) }
#  <t(A,144) >
#  {f (A,144) }
#  <t(A,145) >
#  {f (A,145) }
#  <t(A,146) >
#  {f (A,146) }
#  <t(A,147) >
#  {f (A,147) }
#  <t(A,148) >
#  {f (A,148) }
#  <t(A,149) >
#  {f (A,149) }
#  <t(A,150) >
#  {f (A,150) }
#  <t(A,106) >
#  {f (A,106) }
#  <t(A,107) >
#  {f (A,107) }
#  <t(A,108) >
#  {f (A,108) }
#  <t(A,109) >
#  {f (A,109) }
#  <t(A,110) >
#  {f (A,110) }
#  <t(A,111) >
#  {f (A,111) }
#  <t(A,112) >
#  {f (A,112) }
#  <t(A,113) >
#  {f (A,113) }
#  <t(A,114) >
#  {f (A,114) }
#  <t(A,115) >
#  {f (A,115) }
#  <t(A,116) >
#  {f (A,116) }
#  <t(A,117) >
#  {f (A,117) }
#  <t(A,118) >
#  {f (A,118) }
#  <t(A,119) >
#  {f (A,119) }
#  <t(A,120) >
#  {f (A,120) }
#  <t(A,121) >
#  {f (A,121) }
#  <t(A,122) >
#  {f (A,122) }
#  <t(A,123) >
#  {f (A,123) }
#  <t(A,124) >
#  {f (A,124) }
#  <t(A,125) >
#  {f (A,125) }
#  <t(A,126) >
#  {f (A,126) }
#  <t(A,127) >
#  {f (A,127) }
#  <t(A,128) >
#  {f (A,128) }
#  <t(A,129) >
#  {f (A,129) }
#  <t(A,130) >
#  {f (A,130) }
#  <t(A,131) >
#  {f (A,131) }
#  <t(A,132) >
#  {f (A,132) }
#  <t(A,133) >
#  {f (A,133) }
#  <t(A,134) >
#  {f (A,134) }
#  <t(A,135) >
#  {f (A,135) }
#  <t(A,76) >
#  {f (A,76) }
#  <t(A,77) >
#  {f (A,77) }
#  <t(A,78) >
#  {f (A,78) }
#  <t(A,79) >
#  {f (A,79) }
#  <t(A,80) >
#  {f (A,80) }
#  <t(A,81) >
#  {f (A,81) }
#  <t(A,82) >
#  {f (A,82) }
#  <t(A,83) >
#  {f (A,83) }
#  <t(A,84) >
#  {f (A,84) }
#  <t(A,85) >
#  {f (A,85) }
#  <t(A,86) >
#  {f (A,86) }
#  <t(A,87) >
#  {f (A,87) }
#  <t(A,88) >
#  {f (A,88) }
#  <t(A,89) >
#  {f (A,89) }
#  <t(A,90) >
#  {f (A,90) }
#  <t(A,91) >
#  {f (A,91) }
#  <t(A,92) >
#  {f (A,92) }
#  <t(A,93) >
#  {f (A,93) }
#  <t(A,94) >
#  {f (A,94) }
#  <t(A,95) >
#  {f (A,95) }
#  <t(A,96) >
#  {f (A,96) }
#  <t(A,97) >
#  {f (A,97) }
#  <t(A,98) >
#  {f (A,98) }
#  <t(A,99) >
#  {f (A,99) }
#  <t(A,100) >
#  {f (A,100) }
#  <t(A,101) >
#  {f (A,101) }
#  <t(A,102) >
#  {f (A,102) }
#  <t(A,103) >
#  {f (A,103) }
#  <t(A,104) >
#  {f (A,104) }
#  <t(A,105) >
#  {f (A,105) }
# ]
#
# "488 nm SIM NA 0.82 3 phases"
# [HWA
#
#  <t(A,136) >
#  {f (A,136) }
#  <t(A,141) >
#  {f (A,141) }
#  <t(A,146) >
#  {f (A,146) }
#  <t(A,106) >
#  {f (A,106) }
#  <t(A,111) >
#  {f (A,111) }
#  <t(A,116) >
#  {f (A,116) }
#  <t(A,121) >
#  {f (A,121) }
#  <t(A,126) >
#  {f (A,126) }
#  <t(A,131) >
#  {f (A,131) }
#  <t(A,76) >
#  {f (A,76) }
#  <t(A,81) >
#  {f (A,81) }
#  <t(A,86) >
#  {f (A,86) }
#  <t(A,91) >
#  {f (A,91) }
#  <t(A,96) >
#  {f (A,96) }
#  <t(A,101) >
#  {f (A,101) }
# ]
#
# "488 nm SIM NA 0.82 5 phases"
# [HWA
#
#  <t(A,136) >
#  {f (A,136) }
#  <t(A,139) >
#  {f (A,139) }
#  <t(A,142) >
#  {f (A,142) }
#  <t(A,145) >
#  {f (A,145) }
#  <t(A,148) >
#  {f (A,148) }
#  <t(A,106) >
#  {f (A,106) }
#  <t(A,109) >
#  {f (A,109) }
#  <t(A,112) >
#  {f (A,112) }
#  <t(A,115) >
#  {f (A,115) }
#  <t(A,118) >
#  {f (A,118) }
#  <t(A,121) >
#  {f (A,121) }
#  <t(A,124) >
#  {f (A,124) }
#  <t(A,127) >
#  {f (A,127) }
#  <t(A,130) >
#  {f (A,130) }
#  <t(A,133) >
#  {f (A,133) }
#  <t(A,76) >
#  {f (A,76) }
#  <t(A,79) >
#  {f (A,79) }
#  <t(A,82) >
#  {f (A,82) }
#  <t(A,85) >
#  {f (A,85) }
#  <t(A,88) >
#  {f (A,88) }
#  <t(A,91) >
#  {f (A,91) }
#  <t(A,94) >
#  {f (A,94) }
#  <t(A,97) >
#  {f (A,97) }
#  <t(A,100) >
#  {f (A,100) }
#  <t(A,103) >
#  {f (A,103) }
# ]
#
# "488 nm NA 0.82 All Orientations Triggered"
# [HWA
#
#  <t(A,151) >
#  {f (A,151) }
# ]
#
# "488 nm NA 0.82 All Orientations"
# [HWA
#
#  {(A,151) }
# ]
#
# "488 nm NA 0.83 +9.00 degrees"
# [HWA
#
#  {(A,212) }
# ]
#
# "488 nm NA 0.83 +45.00 degrees"
# [HWA
#
#  {(A,182) }
# ]
#
# "488 nm NA 0.83 +81.00 degrees"
# [HWA
#
#  {(A,197) }
# ]
#
# "488 nm NA 0.83 +117.00 degrees"
# [HWA
#
#  {(A,152) }
# ]
#
# "488 nm NA 0.83 +153.00 degrees"
# [HWA
#
#  {(A,167) }
# ]
#
# "488 nm Super SIM 2pi NA 0.83"
# [HWA
#
#  <t(A,212) >
#  {f (A,212) }
#  <t(A,213) >
#  {f (A,213) }
#  <t(A,214) >
#  {f (A,214) }
#  <t(A,215) >
#  {f (A,215) }
#  <t(A,216) >
#  {f (A,216) }
#  <t(A,217) >
#  {f (A,217) }
#  <t(A,218) >
#  {f (A,218) }
#  <t(A,219) >
#  {f (A,219) }
#  <t(A,220) >
#  {f (A,220) }
#  <t(A,221) >
#  {f (A,221) }
#  <t(A,222) >
#  {f (A,222) }
#  <t(A,223) >
#  {f (A,223) }
#  <t(A,224) >
#  {f (A,224) }
#  <t(A,225) >
#  {f (A,225) }
#  <t(A,226) >
#  {f (A,226) }
#  <t(A,182) >
#  {f (A,182) }
#  <t(A,183) >
#  {f (A,183) }
#  <t(A,184) >
#  {f (A,184) }
#  <t(A,185) >
#  {f (A,185) }
#  <t(A,186) >
#  {f (A,186) }
#  <t(A,187) >
#  {f (A,187) }
#  <t(A,188) >
#  {f (A,188) }
#  <t(A,189) >
#  {f (A,189) }
#  <t(A,190) >
#  {f (A,190) }
#  <t(A,191) >
#  {f (A,191) }
#  <t(A,192) >
#  {f (A,192) }
#  <t(A,193) >
#  {f (A,193) }
#  <t(A,194) >
#  {f (A,194) }
#  <t(A,195) >
#  {f (A,195) }
#  <t(A,196) >
#  {f (A,196) }
#  <t(A,197) >
#  {f (A,197) }
#  <t(A,198) >
#  {f (A,198) }
#  <t(A,199) >
#  {f (A,199) }
#  <t(A,200) >
#  {f (A,200) }
#  <t(A,201) >
#  {f (A,201) }
#  <t(A,202) >
#  {f (A,202) }
#  <t(A,203) >
#  {f (A,203) }
#  <t(A,204) >
#  {f (A,204) }
#  <t(A,205) >
#  {f (A,205) }
#  <t(A,206) >
#  {f (A,206) }
#  <t(A,207) >
#  {f (A,207) }
#  <t(A,208) >
#  {f (A,208) }
#  <t(A,209) >
#  {f (A,209) }
#  <t(A,210) >
#  {f (A,210) }
#  <t(A,211) >
#  {f (A,211) }
#  <t(A,152) >
#  {f (A,152) }
#  <t(A,153) >
#  {f (A,153) }
#  <t(A,154) >
#  {f (A,154) }
#  <t(A,155) >
#  {f (A,155) }
#  <t(A,156) >
#  {f (A,156) }
#  <t(A,157) >
#  {f (A,157) }
#  <t(A,158) >
#  {f (A,158) }
#  <t(A,159) >
#  {f (A,159) }
#  <t(A,160) >
#  {f (A,160) }
#  <t(A,161) >
#  {f (A,161) }
#  <t(A,162) >
#  {f (A,162) }
#  <t(A,163) >
#  {f (A,163) }
#  <t(A,164) >
#  {f (A,164) }
#  <t(A,165) >
#  {f (A,165) }
#  <t(A,166) >
#  {f (A,166) }
#  <t(A,167) >
#  {f (A,167) }
#  <t(A,168) >
#  {f (A,168) }
#  <t(A,169) >
#  {f (A,169) }
#  <t(A,170) >
#  {f (A,170) }
#  <t(A,171) >
#  {f (A,171) }
#  <t(A,172) >
#  {f (A,172) }
#  <t(A,173) >
#  {f (A,173) }
#  <t(A,174) >
#  {f (A,174) }
#  <t(A,175) >
#  {f (A,175) }
#  <t(A,176) >
#  {f (A,176) }
#  <t(A,177) >
#  {f (A,177) }
#  <t(A,178) >
#  {f (A,178) }
#  <t(A,179) >
#  {f (A,179) }
#  <t(A,180) >
#  {f (A,180) }
#  <t(A,181) >
#  {f (A,181) }
# ]
#
# "488 nm SIM NA 0.83 3 phases"
# [HWA
#
#  <t(A,212) >
#  {f (A,212) }
#  <t(A,217) >
#  {f (A,217) }
#  <t(A,222) >
#  {f (A,222) }
#  <t(A,182) >
#  {f (A,182) }
#  <t(A,187) >
#  {f (A,187) }
#  <t(A,192) >
#  {f (A,192) }
#  <t(A,197) >
#  {f (A,197) }
#  <t(A,202) >
#  {f (A,202) }
#  <t(A,207) >
#  {f (A,207) }
#  <t(A,152) >
#  {f (A,152) }
#  <t(A,157) >
#  {f (A,157) }
#  <t(A,162) >
#  {f (A,162) }
#  <t(A,167) >
#  {f (A,167) }
#  <t(A,172) >
#  {f (A,172) }
#  <t(A,177) >
#  {f (A,177) }
# ]
#
# "488 nm SIM NA 0.83 5 phases"
# [HWA
#
#  <t(A,212) >
#  {f (A,212) }
#  <t(A,215) >
#  {f (A,215) }
#  <t(A,218) >
#  {f (A,218) }
#  <t(A,221) >
#  {f (A,221) }
#  <t(A,224) >
#  {f (A,224) }
#  <t(A,182) >
#  {f (A,182) }
#  <t(A,185) >
#  {f (A,185) }
#  <t(A,188) >
#  {f (A,188) }
#  <t(A,191) >
#  {f (A,191) }
#  <t(A,194) >
#  {f (A,194) }
#  <t(A,197) >
#  {f (A,197) }
#  <t(A,200) >
#  {f (A,200) }
#  <t(A,203) >
#  {f (A,203) }
#  <t(A,206) >
#  {f (A,206) }
#  <t(A,209) >
#  {f (A,209) }
#  <t(A,152) >
#  {f (A,152) }
#  <t(A,155) >
#  {f (A,155) }
#  <t(A,158) >
#  {f (A,158) }
#  <t(A,161) >
#  {f (A,161) }
#  <t(A,164) >
#  {f (A,164) }
#  <t(A,167) >
#  {f (A,167) }
#  <t(A,170) >
#  {f (A,170) }
#  <t(A,173) >
#  {f (A,173) }
#  <t(A,176) >
#  {f (A,176) }
#  <t(A,179) >
#  {f (A,179) }
# ]
#
# "488 nm NA 0.83 All Orientations Triggered"
# [HWA
#
#  <t(A,227) >
#  {f (A,227) }
# ]
#
# "488 nm NA 0.83 All Orientations"
# [HWA
#
#  {(A,227) }
# ]
#
# "488 nm NA 0.84 +9.00 degrees"
# [HWA
#
#  {(A,288) }
# ]
#
# "488 nm NA 0.84 +45.00 degrees"
# [HWA
#
#  {(A,258) }
# ]
#
# "488 nm NA 0.84 +81.00 degrees"
# [HWA
#
#  {(A,273) }
# ]
#
# "488 nm NA 0.84 +117.00 degrees"
# [HWA
#
#  {(A,228) }
# ]
#
# "488 nm NA 0.84 +153.00 degrees"
# [HWA
#
#  {(A,243) }
# ]
#
# "488 nm Super SIM 2pi NA 0.84"
# [HWA
#
#  <t(A,288) >
#  {f (A,288) }
#  <t(A,289) >
#  {f (A,289) }
#  <t(A,290) >
#  {f (A,290) }
#  <t(A,291) >
#  {f (A,291) }
#  <t(A,292) >
#  {f (A,292) }
#  <t(A,293) >
#  {f (A,293) }
#  <t(A,294) >
#  {f (A,294) }
#  <t(A,295) >
#  {f (A,295) }
#  <t(A,296) >
#  {f (A,296) }
#  <t(A,297) >
#  {f (A,297) }
#  <t(A,298) >
#  {f (A,298) }
#  <t(A,299) >
#  {f (A,299) }
#  <t(A,300) >
#  {f (A,300) }
#  <t(A,301) >
#  {f (A,301) }
#  <t(A,302) >
#  {f (A,302) }
#  <t(A,258) >
#  {f (A,258) }
#  <t(A,259) >
#  {f (A,259) }
#  <t(A,260) >
#  {f (A,260) }
#  <t(A,261) >
#  {f (A,261) }
#  <t(A,262) >
#  {f (A,262) }
#  <t(A,263) >
#  {f (A,263) }
#  <t(A,264) >
#  {f (A,264) }
#  <t(A,265) >
#  {f (A,265) }
#  <t(A,266) >
#  {f (A,266) }
#  <t(A,267) >
#  {f (A,267) }
#  <t(A,268) >
#  {f (A,268) }
#  <t(A,269) >
#  {f (A,269) }
#  <t(A,270) >
#  {f (A,270) }
#  <t(A,271) >
#  {f (A,271) }
#  <t(A,272) >
#  {f (A,272) }
#  <t(A,273) >
#  {f (A,273) }
#  <t(A,274) >
#  {f (A,274) }
#  <t(A,275) >
#  {f (A,275) }
#  <t(A,276) >
#  {f (A,276) }
#  <t(A,277) >
#  {f (A,277) }
#  <t(A,278) >
#  {f (A,278) }
#  <t(A,279) >
#  {f (A,279) }
#  <t(A,280) >
#  {f (A,280) }
#  <t(A,281) >
#  {f (A,281) }
#  <t(A,282) >
#  {f (A,282) }
#  <t(A,283) >
#  {f (A,283) }
#  <t(A,284) >
#  {f (A,284) }
#  <t(A,285) >
#  {f (A,285) }
#  <t(A,286) >
#  {f (A,286) }
#  <t(A,287) >
#  {f (A,287) }
#  <t(A,228) >
#  {f (A,228) }
#  <t(A,229) >
#  {f (A,229) }
#  <t(A,230) >
#  {f (A,230) }
#  <t(A,231) >
#  {f (A,231) }
#  <t(A,232) >
#  {f (A,232) }
#  <t(A,233) >
#  {f (A,233) }
#  <t(A,234) >
#  {f (A,234) }
#  <t(A,235) >
#  {f (A,235) }
#  <t(A,236) >
#  {f (A,236) }
#  <t(A,237) >
#  {f (A,237) }
#  <t(A,238) >
#  {f (A,238) }
#  <t(A,239) >
#  {f (A,239) }
#  <t(A,240) >
#  {f (A,240) }
#  <t(A,241) >
#  {f (A,241) }
#  <t(A,242) >
#  {f (A,242) }
#  <t(A,243) >
#  {f (A,243) }
#  <t(A,244) >
#  {f (A,244) }
#  <t(A,245) >
#  {f (A,245) }
#  <t(A,246) >
#  {f (A,246) }
#  <t(A,247) >
#  {f (A,247) }
#  <t(A,248) >
#  {f (A,248) }
#  <t(A,249) >
#  {f (A,249) }
#  <t(A,250) >
#  {f (A,250) }
#  <t(A,251) >
#  {f (A,251) }
#  <t(A,252) >
#  {f (A,252) }
#  <t(A,253) >
#  {f (A,253) }
#  <t(A,254) >
#  {f (A,254) }
#  <t(A,255) >
#  {f (A,255) }
#  <t(A,256) >
#  {f (A,256) }
#  <t(A,257) >
#  {f (A,257) }
# ]
#
# "488 nm SIM NA 0.84 3 phases"
# [HWA
#
#  <t(A,288) >
#  {f (A,288) }
#  <t(A,293) >
#  {f (A,293) }
#  <t(A,298) >
#  {f (A,298) }
#  <t(A,258) >
#  {f (A,258) }
#  <t(A,263) >
#  {f (A,263) }
#  <t(A,268) >
#  {f (A,268) }
#  <t(A,273) >
#  {f (A,273) }
#  <t(A,278) >
#  {f (A,278) }
#  <t(A,283) >
#  {f (A,283) }
#  <t(A,228) >
#  {f (A,228) }
#  <t(A,233) >
#  {f (A,233) }
#  <t(A,238) >
#  {f (A,238) }
#  <t(A,243) >
#  {f (A,243) }
#  <t(A,248) >
#  {f (A,248) }
#  <t(A,253) >
#  {f (A,253) }
# ]
#
# "488 nm SIM NA 0.84 5 phases"
# [HWA
#
#  <t(A,288) >
#  {f (A,288) }
#  <t(A,291) >
#  {f (A,291) }
#  <t(A,294) >
#  {f (A,294) }
#  <t(A,297) >
#  {f (A,297) }
#  <t(A,300) >
#  {f (A,300) }
#  <t(A,258) >
#  {f (A,258) }
#  <t(A,261) >
#  {f (A,261) }
#  <t(A,264) >
#  {f (A,264) }
#  <t(A,267) >
#  {f (A,267) }
#  <t(A,270) >
#  {f (A,270) }
#  <t(A,273) >
#  {f (A,273) }
#  <t(A,276) >
#  {f (A,276) }
#  <t(A,279) >
#  {f (A,279) }
#  <t(A,282) >
#  {f (A,282) }
#  <t(A,285) >
#  {f (A,285) }
#  <t(A,228) >
#  {f (A,228) }
#  <t(A,231) >
#  {f (A,231) }
#  <t(A,234) >
#  {f (A,234) }
#  <t(A,237) >
#  {f (A,237) }
#  <t(A,240) >
#  {f (A,240) }
#  <t(A,243) >
#  {f (A,243) }
#  <t(A,246) >
#  {f (A,246) }
#  <t(A,249) >
#  {f (A,249) }
#  <t(A,252) >
#  {f (A,252) }
#  <t(A,255) >
#  {f (A,255) }
# ]
#
# "488 nm NA 0.84 All Orientations Triggered"
# [HWA
#
#  <t(A,303) >
#  {f (A,303) }
# ]
#
# "488 nm NA 0.84 All Orientations"
# [HWA
#
#  {(A,303) }
# ]

# %%
# Super SIM for 5 orientations
onfrac = 0.5
num_angles = 5
my_angles = angles(deg2rad(9.0),num_angles)
    
num_phases = 15
num_periods = 1

wls = (488,)

repname = 'SuperSIM488_2D_5orients_9deg'
# open zip file, make sure the compression is set to ZIP_DEFLATED (8)
with zipfile.ZipFile('{}.repz11'.format(repname), 'w', compression=zipfile.ZIP_DEFLATED) as myzip:

    opt = False

    my_dir = os.path.join('{}'.format(repname),'')
    if not os.path.isdir(my_dir):
        print('Making '+my_dir)
        os.mkdir(my_dir)
    
    NAs = (0.81, 0.82) #, 0.83, 0.84)
    
    ROlist = []
    
    seq = '48070 HHMI 10ms.seq11'
    
    for myseq in (seq,):
        myzip.write(os.path.join('HHMI_R11_Seq', myseq),arcname=myseq)
    
    for wl in wls:
        for NA in NAs:
            print('{} nm, NA {}'.format(wl,NA))

            iperiod = ideal_period(wl,NA=NA)
            # ROs here
            super_RO = RunningOrder('{} nm Super SIM {}pi NA {}'.format(wl, num_periods*2, NA),
                                    angles=num_angles, periods=num_periods)
            reg_RO_3 = RunningOrder('{} nm SIM NA {} 3 phases'.format(wl,NA), angles=num_angles)
            reg_RO_5 = RunningOrder('{} nm SIM NA {} 5 phases'.format(wl,NA), angles=num_angles)

            RO_all_t = RunningOrder('{} nm NA {} All Orientations Triggered'.format(wl,NA), angles=1)
            RO_all = RunningOrder('{} nm NA {} All Orientations'.format(wl,NA), triggered=False, angles=1)

            patall =zeros((1536, 2048))

            for angle in my_angles:

                # calculate degree from angle for filename
                degree = rad2deg(angle)

                RO1orient = RunningOrder('{} nm NA {} {:+.2f} degrees'.format(wl, NA, degree), angles=1, triggered=False)

                # optimize the angle
                if opt:
                    print('Optimizing angle = {:+.2f} degrees'.format(degree))
                    my_per = opt_period(iperiod,angle)[0]
                else:
                    my_per = iperiod

                for phase in range(num_phases):
                    # generate pattern, with one period,
                    pat = pattern_gen(angle, my_per,onfrac=onfrac,phase_idx=phase,nphases=num_phases,SIM_2D=True)

                    # make image object
                    pat_img = Image.fromarray((pat*255).astype('uint8'),mode='L')

                    # generate filename, put orientation in front, so that its consistent
                    name = 'pat-{}nm-{:.2f}NA{:+.1f}deg-{:02d}ph-{:.4f}pix-{:.2f}DC.bmp'.format(wl,NA, degree,phase,my_per,onfrac)

                    # convert to binary and save
                    pat_img.convert('1').save(os.path.join(my_dir,name))

                    # move to zip file and save
                    myzip.write(os.path.join(my_dir,name),arcname=name)

                    super_RO.addbitplane(seq,name)

                    if not phase:
                        RO1orient.addbitplane(seq,name)
                        # add to all angles pattern
                        patall += pat

                    # only pull the first three phases so that we can do regular SIM too
                    if (phase % (num_phases//3) == 0):
                        # num_phases//desired number of phases will calculate the right divisor
                        # check
                        assert num_phases % 3 == 0
                        reg_RO_3.addbitplane(seq,name)
                    if (phase % (num_phases//5) == 0):
                        assert num_phases % 5 == 0
                        reg_RO_5.addbitplane(seq,name)

                    print('Wrote file: {}'.format(name))

                ROlist.append(RO1orient)

            # make image object for all
            patall_img = Image.fromarray((patall/num_angles*255).astype('uint8'),mode='L')

            # generate filename, put orientation in front, so that its consistent
            nameall = 'pat-{}nm-{:.2f}NA-{:.4f}pix-{:.2f}DC_allangles.bmp'.format(wl,NA,my_per,onfrac)

            # convert to binary and save
            patall_img.convert('1').save(os.path.join(my_dir,nameall))

            # move to zip file and save
            myzip.write(os.path.join(my_dir,nameall),arcname=nameall)

            RO_all_t.addbitplane(seq,nameall)
            RO_all.addbitplane(seq,nameall)

            ROlist.append(super_RO)
            ROlist.append(reg_RO_3)
            ROlist.append(reg_RO_5)
            ROlist.append(RO_all_t)
            ROlist.append(RO_all)
                
    my_Rep = Repetoire(ROlist)
    
    # write the rep file
    with open(os.path.join(my_dir,'{}.rep'.format(repname)),'w') as repfile:
        repfile.write(str(my_Rep))
        
    # now add the file to the zip
    myzip.write(os.path.join(my_dir,'{}.rep'.format(repname)),arcname='{}.rep'.format(repname))
    
print(my_Rep)
# Out:
# 488 nm, NA 0.81
# Wrote file: pat-488nm-0.81NA+9.0deg-00ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-01ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-02ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-03ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-04ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-05ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-06ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-07ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-08ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-09ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-10ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-11ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-12ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-13ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+9.0deg-14ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-00ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-01ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-02ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-03ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-04ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-05ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-06ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-07ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-08ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-09ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-10ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-11ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-12ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-13ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+45.0deg-14ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-00ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-01ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-02ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-03ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-04ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-05ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-06ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-07ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-08ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-09ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-10ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-11ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-12ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-13ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+81.0deg-14ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-00ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-01ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-02ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-03ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-04ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-05ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-06ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-07ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-08ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-09ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-10ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-11ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-12ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-13ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+117.0deg-14ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-00ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-01ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-02ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-03ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-04ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-05ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-06ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-07ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-08ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-09ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-10ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-11ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-12ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-13ph-6.2513pix-0.50DC.bmp
# Wrote file: pat-488nm-0.81NA+153.0deg-14ph-6.2513pix-0.50DC.bmp
# 488 nm, NA 0.82
# Wrote file: pat-488nm-0.82NA+9.0deg-00ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-01ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-02ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-03ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-04ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-05ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-06ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-07ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-08ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-09ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-10ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-11ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-12ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-13ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+9.0deg-14ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-00ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-01ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-02ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-03ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-04ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-05ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-06ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-07ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-08ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-09ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-10ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-11ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-12ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-13ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+45.0deg-14ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-00ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-01ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-02ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-03ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-04ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-05ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-06ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-07ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-08ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-09ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-10ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-11ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-12ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-13ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+81.0deg-14ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-00ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-01ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-02ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-03ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-04ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-05ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-06ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-07ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-08ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-09ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-10ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-11ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-12ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-13ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+117.0deg-14ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-00ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-01ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-02ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-03ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-04ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-05ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-06ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-07ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-08ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-09ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-10ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-11ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-12ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-13ph-6.1735pix-0.50DC.bmp
# Wrote file: pat-488nm-0.82NA+153.0deg-14ph-6.1735pix-0.50DC.bmp
# SEQUENCES
# A "48070 HHMI 10ms.seq11"
# SEQUENCES_END
#
# IMAGES
# 1 "pat-488nm-0.81NA+117.0deg-00ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-01ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-02ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-03ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-04ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-05ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-06ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-07ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-08ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-09ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-10ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-11ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-12ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-13ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+117.0deg-14ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-00ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-01ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-02ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-03ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-04ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-05ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-06ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-07ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-08ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-09ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-10ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-11ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-12ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-13ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+153.0deg-14ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-00ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-01ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-02ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-03ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-04ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-05ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-06ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-07ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-08ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-09ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-10ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-11ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-12ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-13ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+45.0deg-14ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-00ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-01ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-02ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-03ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-04ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-05ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-06ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-07ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-08ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-09ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-10ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-11ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-12ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-13ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+81.0deg-14ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-00ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-01ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-02ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-03ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-04ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-05ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-06ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-07ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-08ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-09ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-10ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-11ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-12ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-13ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA+9.0deg-14ph-6.2513pix-0.50DC.bmp"
# 1 "pat-488nm-0.81NA-6.2513pix-0.50DC_allangles.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-00ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-01ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-02ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-03ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-04ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-05ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-06ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-07ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-08ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-09ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-10ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-11ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-12ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-13ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+117.0deg-14ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-00ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-01ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-02ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-03ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-04ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-05ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-06ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-07ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-08ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-09ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-10ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-11ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-12ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-13ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+153.0deg-14ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-00ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-01ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-02ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-03ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-04ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-05ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-06ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-07ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-08ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-09ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-10ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-11ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-12ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-13ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+45.0deg-14ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-00ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-01ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-02ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-03ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-04ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-05ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-06ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-07ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-08ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-09ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-10ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-11ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-12ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-13ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+81.0deg-14ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-00ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-01ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-02ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-03ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-04ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-05ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-06ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-07ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-08ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-09ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-10ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-11ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-12ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-13ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA+9.0deg-14ph-6.1735pix-0.50DC.bmp"
# 1 "pat-488nm-0.82NA-6.1735pix-0.50DC_allangles.bmp"
# IMAGES_END
#
# DEFAULT "488 nm NA 0.81 +9.00 degrees"
# [HWA
#
#  {(A,60) }
# ]
#
# "488 nm NA 0.81 +45.00 degrees"
# [HWA
#
#  {(A,30) }
# ]
#
# "488 nm NA 0.81 +81.00 degrees"
# [HWA
#
#  {(A,45) }
# ]
#
# "488 nm NA 0.81 +117.00 degrees"
# [HWA
#
#  {(A,0) }
# ]
#
# "488 nm NA 0.81 +153.00 degrees"
# [HWA
#
#  {(A,15) }
# ]
#
# "488 nm Super SIM 2pi NA 0.81"
# [HWA
#
#  <t(A,60) >
#  {f (A,60) }
#  <t(A,61) >
#  {f (A,61) }
#  <t(A,62) >
#  {f (A,62) }
#  <t(A,63) >
#  {f (A,63) }
#  <t(A,64) >
#  {f (A,64) }
#  <t(A,65) >
#  {f (A,65) }
#  <t(A,66) >
#  {f (A,66) }
#  <t(A,67) >
#  {f (A,67) }
#  <t(A,68) >
#  {f (A,68) }
#  <t(A,69) >
#  {f (A,69) }
#  <t(A,70) >
#  {f (A,70) }
#  <t(A,71) >
#  {f (A,71) }
#  <t(A,72) >
#  {f (A,72) }
#  <t(A,73) >
#  {f (A,73) }
#  <t(A,74) >
#  {f (A,74) }
#  <t(A,30) >
#  {f (A,30) }
#  <t(A,31) >
#  {f (A,31) }
#  <t(A,32) >
#  {f (A,32) }
#  <t(A,33) >
#  {f (A,33) }
#  <t(A,34) >
#  {f (A,34) }
#  <t(A,35) >
#  {f (A,35) }
#  <t(A,36) >
#  {f (A,36) }
#  <t(A,37) >
#  {f (A,37) }
#  <t(A,38) >
#  {f (A,38) }
#  <t(A,39) >
#  {f (A,39) }
#  <t(A,40) >
#  {f (A,40) }
#  <t(A,41) >
#  {f (A,41) }
#  <t(A,42) >
#  {f (A,42) }
#  <t(A,43) >
#  {f (A,43) }
#  <t(A,44) >
#  {f (A,44) }
#  <t(A,45) >
#  {f (A,45) }
#  <t(A,46) >
#  {f (A,46) }
#  <t(A,47) >
#  {f (A,47) }
#  <t(A,48) >
#  {f (A,48) }
#  <t(A,49) >
#  {f (A,49) }
#  <t(A,50) >
#  {f (A,50) }
#  <t(A,51) >
#  {f (A,51) }
#  <t(A,52) >
#  {f (A,52) }
#  <t(A,53) >
#  {f (A,53) }
#  <t(A,54) >
#  {f (A,54) }
#  <t(A,55) >
#  {f (A,55) }
#  <t(A,56) >
#  {f (A,56) }
#  <t(A,57) >
#  {f (A,57) }
#  <t(A,58) >
#  {f (A,58) }
#  <t(A,59) >
#  {f (A,59) }
#  <t(A,0) >
#  {f (A,0) }
#  <t(A,1) >
#  {f (A,1) }
#  <t(A,2) >
#  {f (A,2) }
#  <t(A,3) >
#  {f (A,3) }
#  <t(A,4) >
#  {f (A,4) }
#  <t(A,5) >
#  {f (A,5) }
#  <t(A,6) >
#  {f (A,6) }
#  <t(A,7) >
#  {f (A,7) }
#  <t(A,8) >
#  {f (A,8) }
#  <t(A,9) >
#  {f (A,9) }
#  <t(A,10) >
#  {f (A,10) }
#  <t(A,11) >
#  {f (A,11) }
#  <t(A,12) >
#  {f (A,12) }
#  <t(A,13) >
#  {f (A,13) }
#  <t(A,14) >
#  {f (A,14) }
#  <t(A,15) >
#  {f (A,15) }
#  <t(A,16) >
#  {f (A,16) }
#  <t(A,17) >
#  {f (A,17) }
#  <t(A,18) >
#  {f (A,18) }
#  <t(A,19) >
#  {f (A,19) }
#  <t(A,20) >
#  {f (A,20) }
#  <t(A,21) >
#  {f (A,21) }
#  <t(A,22) >
#  {f (A,22) }
#  <t(A,23) >
#  {f (A,23) }
#  <t(A,24) >
#  {f (A,24) }
#  <t(A,25) >
#  {f (A,25) }
#  <t(A,26) >
#  {f (A,26) }
#  <t(A,27) >
#  {f (A,27) }
#  <t(A,28) >
#  {f (A,28) }
#  <t(A,29) >
#  {f (A,29) }
# ]
#
# "488 nm SIM NA 0.81 3 phases"
# [HWA
#
#  <t(A,60) >
#  {f (A,60) }
#  <t(A,65) >
#  {f (A,65) }
#  <t(A,70) >
#  {f (A,70) }
#  <t(A,30) >
#  {f (A,30) }
#  <t(A,35) >
#  {f (A,35) }
#  <t(A,40) >
#  {f (A,40) }
#  <t(A,45) >
#  {f (A,45) }
#  <t(A,50) >
#  {f (A,50) }
#  <t(A,55) >
#  {f (A,55) }
#  <t(A,0) >
#  {f (A,0) }
#  <t(A,5) >
#  {f (A,5) }
#  <t(A,10) >
#  {f (A,10) }
#  <t(A,15) >
#  {f (A,15) }
#  <t(A,20) >
#  {f (A,20) }
#  <t(A,25) >
#  {f (A,25) }
# ]
#
# "488 nm SIM NA 0.81 5 phases"
# [HWA
#
#  <t(A,60) >
#  {f (A,60) }
#  <t(A,63) >
#  {f (A,63) }
#  <t(A,66) >
#  {f (A,66) }
#  <t(A,69) >
#  {f (A,69) }
#  <t(A,72) >
#  {f (A,72) }
#  <t(A,30) >
#  {f (A,30) }
#  <t(A,33) >
#  {f (A,33) }
#  <t(A,36) >
#  {f (A,36) }
#  <t(A,39) >
#  {f (A,39) }
#  <t(A,42) >
#  {f (A,42) }
#  <t(A,45) >
#  {f (A,45) }
#  <t(A,48) >
#  {f (A,48) }
#  <t(A,51) >
#  {f (A,51) }
#  <t(A,54) >
#  {f (A,54) }
#  <t(A,57) >
#  {f (A,57) }
#  <t(A,0) >
#  {f (A,0) }
#  <t(A,3) >
#  {f (A,3) }
#  <t(A,6) >
#  {f (A,6) }
#  <t(A,9) >
#  {f (A,9) }
#  <t(A,12) >
#  {f (A,12) }
#  <t(A,15) >
#  {f (A,15) }
#  <t(A,18) >
#  {f (A,18) }
#  <t(A,21) >
#  {f (A,21) }
#  <t(A,24) >
#  {f (A,24) }
#  <t(A,27) >
#  {f (A,27) }
# ]
#
# "488 nm NA 0.81 All Orientations Triggered"
# [HWA
#
#  <t(A,75) >
#  {f (A,75) }
# ]
#
# "488 nm NA 0.81 All Orientations"
# [HWA
#
#  {(A,75) }
# ]
#
# "488 nm NA 0.82 +9.00 degrees"
# [HWA
#
#  {(A,136) }
# ]
#
# "488 nm NA 0.82 +45.00 degrees"
# [HWA
#
#  {(A,106) }
# ]
#
# "488 nm NA 0.82 +81.00 degrees"
# [HWA
#
#  {(A,121) }
# ]
#
# "488 nm NA 0.82 +117.00 degrees"
# [HWA
#
#  {(A,76) }
# ]
#
# "488 nm NA 0.82 +153.00 degrees"
# [HWA
#
#  {(A,91) }
# ]
#
# "488 nm Super SIM 2pi NA 0.82"
# [HWA
#
#  <t(A,136) >
#  {f (A,136) }
#  <t(A,137) >
#  {f (A,137) }
#  <t(A,138) >
#  {f (A,138) }
#  <t(A,139) >
#  {f (A,139) }
#  <t(A,140) >
#  {f (A,140) }
#  <t(A,141) >
#  {f (A,141) }
#  <t(A,142) >
#  {f (A,142) }
#  <t(A,143) >
#  {f (A,143) }
#  <t(A,144) >
#  {f (A,144) }
#  <t(A,145) >
#  {f (A,145) }
#  <t(A,146) >
#  {f (A,146) }
#  <t(A,147) >
#  {f (A,147) }
#  <t(A,148) >
#  {f (A,148) }
#  <t(A,149) >
#  {f (A,149) }
#  <t(A,150) >
#  {f (A,150) }
#  <t(A,106) >
#  {f (A,106) }
#  <t(A,107) >
#  {f (A,107) }
#  <t(A,108) >
#  {f (A,108) }
#  <t(A,109) >
#  {f (A,109) }
#  <t(A,110) >
#  {f (A,110) }
#  <t(A,111) >
#  {f (A,111) }
#  <t(A,112) >
#  {f (A,112) }
#  <t(A,113) >
#  {f (A,113) }
#  <t(A,114) >
#  {f (A,114) }
#  <t(A,115) >
#  {f (A,115) }
#  <t(A,116) >
#  {f (A,116) }
#  <t(A,117) >
#  {f (A,117) }
#  <t(A,118) >
#  {f (A,118) }
#  <t(A,119) >
#  {f (A,119) }
#  <t(A,120) >
#  {f (A,120) }
#  <t(A,121) >
#  {f (A,121) }
#  <t(A,122) >
#  {f (A,122) }
#  <t(A,123) >
#  {f (A,123) }
#  <t(A,124) >
#  {f (A,124) }
#  <t(A,125) >
#  {f (A,125) }
#  <t(A,126) >
#  {f (A,126) }
#  <t(A,127) >
#  {f (A,127) }
#  <t(A,128) >
#  {f (A,128) }
#  <t(A,129) >
#  {f (A,129) }
#  <t(A,130) >
#  {f (A,130) }
#  <t(A,131) >
#  {f (A,131) }
#  <t(A,132) >
#  {f (A,132) }
#  <t(A,133) >
#  {f (A,133) }
#  <t(A,134) >
#  {f (A,134) }
#  <t(A,135) >
#  {f (A,135) }
#  <t(A,76) >
#  {f (A,76) }
#  <t(A,77) >
#  {f (A,77) }
#  <t(A,78) >
#  {f (A,78) }
#  <t(A,79) >
#  {f (A,79) }
#  <t(A,80) >
#  {f (A,80) }
#  <t(A,81) >
#  {f (A,81) }
#  <t(A,82) >
#  {f (A,82) }
#  <t(A,83) >
#  {f (A,83) }
#  <t(A,84) >
#  {f (A,84) }
#  <t(A,85) >
#  {f (A,85) }
#  <t(A,86) >
#  {f (A,86) }
#  <t(A,87) >
#  {f (A,87) }
#  <t(A,88) >
#  {f (A,88) }
#  <t(A,89) >
#  {f (A,89) }
#  <t(A,90) >
#  {f (A,90) }
#  <t(A,91) >
#  {f (A,91) }
#  <t(A,92) >
#  {f (A,92) }
#  <t(A,93) >
#  {f (A,93) }
#  <t(A,94) >
#  {f (A,94) }
#  <t(A,95) >
#  {f (A,95) }
#  <t(A,96) >
#  {f (A,96) }
#  <t(A,97) >
#  {f (A,97) }
#  <t(A,98) >
#  {f (A,98) }
#  <t(A,99) >
#  {f (A,99) }
#  <t(A,100) >
#  {f (A,100) }
#  <t(A,101) >
#  {f (A,101) }
#  <t(A,102) >
#  {f (A,102) }
#  <t(A,103) >
#  {f (A,103) }
#  <t(A,104) >
#  {f (A,104) }
#  <t(A,105) >
#  {f (A,105) }
# ]
#
# "488 nm SIM NA 0.82 3 phases"
# [HWA
#
#  <t(A,136) >
#  {f (A,136) }
#  <t(A,141) >
#  {f (A,141) }
#  <t(A,146) >
#  {f (A,146) }
#  <t(A,106) >
#  {f (A,106) }
#  <t(A,111) >
#  {f (A,111) }
#  <t(A,116) >
#  {f (A,116) }
#  <t(A,121) >
#  {f (A,121) }
#  <t(A,126) >
#  {f (A,126) }
#  <t(A,131) >
#  {f (A,131) }
#  <t(A,76) >
#  {f (A,76) }
#  <t(A,81) >
#  {f (A,81) }
#  <t(A,86) >
#  {f (A,86) }
#  <t(A,91) >
#  {f (A,91) }
#  <t(A,96) >
#  {f (A,96) }
#  <t(A,101) >
#  {f (A,101) }
# ]
#
# "488 nm SIM NA 0.82 5 phases"
# [HWA
#
#  <t(A,136) >
#  {f (A,136) }
#  <t(A,139) >
#  {f (A,139) }
#  <t(A,142) >
#  {f (A,142) }
#  <t(A,145) >
#  {f (A,145) }
#  <t(A,148) >
#  {f (A,148) }
#  <t(A,106) >
#  {f (A,106) }
#  <t(A,109) >
#  {f (A,109) }
#  <t(A,112) >
#  {f (A,112) }
#  <t(A,115) >
#  {f (A,115) }
#  <t(A,118) >
#  {f (A,118) }
#  <t(A,121) >
#  {f (A,121) }
#  <t(A,124) >
#  {f (A,124) }
#  <t(A,127) >
#  {f (A,127) }
#  <t(A,130) >
#  {f (A,130) }
#  <t(A,133) >
#  {f (A,133) }
#  <t(A,76) >
#  {f (A,76) }
#  <t(A,79) >
#  {f (A,79) }
#  <t(A,82) >
#  {f (A,82) }
#  <t(A,85) >
#  {f (A,85) }
#  <t(A,88) >
#  {f (A,88) }
#  <t(A,91) >
#  {f (A,91) }
#  <t(A,94) >
#  {f (A,94) }
#  <t(A,97) >
#  {f (A,97) }
#  <t(A,100) >
#  {f (A,100) }
#  <t(A,103) >
#  {f (A,103) }
# ]
#
# "488 nm NA 0.82 All Orientations Triggered"
# [HWA
#
#  <t(A,151) >
#  {f (A,151) }
# ]
#
# "488 nm NA 0.82 All Orientations"
# [HWA
#
#  {(A,151) }
# ]
